# %% [markdown]
# ## Introduction
# In this lab, we would like to make an XGBoost model to study the e-commerce behavior from a multi-category store. First, we need to download the data to your local machine, then we will load the data into a Pandas DataFrame.

# %% [markdown]
# ## Objectives
# - Apply XGBoost to an example

# %% [markdown]
# ## Instruction
# * Accept the Kaggle policy and download the data from [Kaggle](https://www.kaggle.com/code/tshephisho/ecommerce-behaviour-using-xgboost/data)
# * For the first model you will only use the 2019-Nov csv data (which is still around ~2gb zipped)

# %%
# import necessary libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as dates
from datetime import datetime

# %%
# fill this in with your path (absolute path works as well)
path_to_file = " "
df = pd.read_csv(path_to_file)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-5-8a93e0211733> in <module>
#       1 # fill this in with your path (absolute path works as well)
#       2 path_to_file = " "
# ----> 3 df = pd.read_csv(path_to_file)
#
# c:\Users\bromoramirez\AppData\Local\anaconda3\envs\learn-env\lib\site-packages\pandas\io\parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     684     )
#     685
# --> 686     return _read(filepath_or_buffer, kwds)
#     687
#     688
#
# c:\Users\bromoramirez\AppData\Local\anaconda3\envs\learn-env\lib\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     450
#     451     # Create the parser.
# --> 452     parser = TextFileReader(fp_or_buf, **kwds)
#     453
#     454     if chunksize or iterator:
#
# c:\Users\bromoramirez\AppData\Local\anaconda3\envs\learn-env\lib\site-packages\pandas\io\parsers.py in __init__(self, f, engine, **kwds)
#     944             self.options["has_index_names"] = kwds["has_index_names"]
#     945
# --> 946         self._make_engine(self.engine)
#     947
#     948     def close(self):
#
# c:\Users\bromoramirez\AppData\Local\anaconda3\envs\learn-env\lib\site-packages\pandas\io\parsers.py in _make_engine(self, engine)
#    1176     def _make_engine(self, engine="c"):
#    1177         if engine == "c":
# -> 1178             self._engine = CParserWrapper(self.f, **self.options)
#    1179         else:
#    1180             if engine == "python":
#
# c:\Users\bromoramirez\AppData\Local\anaconda3\envs\learn-env\lib\site-packages\pandas\io\parsers.py in __init__(self, src, **kwds)
#    2006         kwds["usecols"] = self.usecols
#    2007
# -> 2008         self._reader = parsers.TextReader(src, **kwds)
#    2009         self.unnamed_cols = self._reader.unnamed_cols
#    2010
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: [Errno 2] No such file or directory: ' '

# %% [markdown]
# Start with some exploratory analysis. First, take a look at the first five rows of the DataFrame. Then get the information about the DataFrame, what is the shape of the DataFrame, and what are the coumn names?

# %%
# your code

df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-c7781961c0cf> in <module>
#       1 # your code
#       2
# ----> 3 df.head()
#
# NameError: name 'df' is not defined

# %%
# your code

df.info()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-ee09bd474a53> in <module>
#       1 # your code
#       2
# ----> 3 df.info()
#
# NameError: name 'df' is not defined

# %%
# your code

visitor = df["user_id"].nunique()
print("visitors: {}".format(visitor))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-31435476908b> in <module>
#       1 # your code
#       2
# ----> 3 visitor = df["user_id"].nunique()
#       4 print("visitors: {}".format(visitor))
#
# NameError: name 'df' is not defined

# %%
# your code
purchase = df.loc[df["event_type"] == "purchase"]
purchase = purchase.dropna(axis="rows")
purchase.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-ff45c467223d> in <module>
#       1 # your code
# ----> 2 purchase = df.loc[df["event_type"] == "purchase"]
#       3 purchase = purchase.dropna(axis="rows")
#       4 purchase.head()
#
# NameError: name 'df' is not defined

# %% [markdown]
# # Know your Customers
# How many unique customers visit the site? Assign the number of visitors to the visitor variable and print it out

# %%
# your code

visitor = df["user_id"].nunique()
print("visitors: {}".format(visitor))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-31435476908b> in <module>
#       1 # your code
#       2
# ----> 3 visitor = df["user_id"].nunique()
#       4 print("visitors: {}".format(visitor))
#
# NameError: name 'df' is not defined

# %% [markdown]
# # Visitors Daily Trend
# Does traffic fluctuate by date? Try using the `event_time` and `user_id` to see traffic. First you need to select by `event_time` and `user_id`, then you will `drop_duplicates` and `groupby` `event_time` and `user_id`.

# %%
d = df.loc[:, ["event_time", "user_id"]]
d["event_time"] = d["event_time"].apply(lambda s: str(s)[0:10])
visitor_by_date = (
    d.drop_duplicates()
    .groupby(["event_time"])["user_id"]
    .agg(["count"])
    .sort_values(by=["event_time"], ascending=True)
)
x = pd.Series(visitor_by_date.index.values).apply(
    lambda s: datetime.strptime(s, "%Y-%m-%d").date()
)
y = visitor_by_date["count"]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-beb708bdae68> in <module>
# ----> 1 d = df.loc[:, ["event_time", "user_id"]]
#       2 d["event_time"] = d["event_time"].apply(lambda s: str(s)[0:10])
#       3 visitor_by_date = (
#       4     d.drop_duplicates()
#       5     .groupby(["event_time"])["user_id"]
#
# NameError: name 'df' is not defined

# %%
plt.rcParams["figure.figsize"] = (17, 5)
plt.plot(x, y)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-3b2796f47e6b> in <module>
#       1 plt.rcParams["figure.figsize"] = (17, 5)
# ----> 2 plt.plot(x, y)
#       3 plt.show()
#
# NameError: name 'x' is not defined

# %% [markdown]
# ### By Category and Product
# Which category do customers interact with the most? What brand do they view the most? You can choose just the categories with at least 30 records in order to construct the plots.

# %%
max_category_num = 30
top_category = (
    df.loc[:, "category_code"]
    .value_counts()[:max_category_num]
    .sort_values(ascending=False)
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-cdb77f85a738> in <module>
#       1 max_category_num = 30
#       2 top_category = (
# ----> 3     df.loc[:, "category_code"]
#       4     .value_counts()[:max_category_num]
#       5     .sort_values(ascending=False)
#
# NameError: name 'df' is not defined

# %%
plt.bar(
    height=top_category,
    x=top_category.index.array,
    color=["red", "cyan", "green", "orange", "blue", "grey"],
    alpha=0.7,
)
plt.axis("off")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-2fc6a01e82be> in <module>
#       1 plt.bar(
# ----> 2     height=top_category,
#       3     x=top_category.index.array,
#       4     color=["red", "cyan", "green", "orange", "blue", "grey"],
#       5     alpha=0.7,
#
# NameError: name 'top_category' is not defined

# %% [markdown]
# ## Purchases
#
# When the event_type is "purchase", what item do customers buy?
#
# Try using `'event_type' == 'purchase'` and drop empty rows to assess which categories customers buy.

# %%
# your code
purchase = df.loc[df["event_type"] == "purchase"]
purchase = purchase.dropna(axis="rows")
purchase.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-ff45c467223d> in <module>
#       1 # your code
# ----> 2 purchase = df.loc[df["event_type"] == "purchase"]
#       3 purchase = purchase.dropna(axis="rows")
#       4 purchase.head()
#
# NameError: name 'df' is not defined

# %% [markdown]
# ## What brands do the customers buy?
# Try grouping by brand and sorting the values by the brand name.

# %%
# your code

top_sellers = (
    purchase.groupby("brand")["brand"]
    .agg(["count"])
    .sort_values("count", ascending=False)
)
top_sellers.head(20)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-2c018be053bd> in <module>
#       2
#       3 top_sellers = (
# ----> 4     purchase.groupby("brand")["brand"]
#       5     .agg(["count"])
#       6     .sort_values("count", ascending=False)
#
# NameError: name 'purchase' is not defined

# %%
del d  # free memory
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-f5d4b52144b7> in <module>
# ----> 1 del d  # free memory
#
# NameError: name 'd' is not defined

# %% [markdown]
# # Modeling: predict at the time of addition to a shopping cart if the user will purchase a given product or not
#
# ### Feature engineering
#
# The goal of this modeling is to predict if the user will purchase a product or not when they add the product to the cart. This is called `cart abandonment` if the user does not purchase.
#
# First, reconstruct and restructure the data to feed into the machine learning model. For this use case, target only the data for which customers have "put" the product into the cart. The relevant `event_type`s are thus "cart" and "purchase".
#
# Create these new features in the training data set:
# - `activity_count`: number of activity in that session
# - `category_level1`: category
# - `category_level2`: sub-category --> split on the "." in the category name
# - `weekday`: weekday of the event --> convert `event_time` to a datetime object, then use `pandas.Timestamp.weekday`
# - `is_purchased`: whether the is purchased after being put in the cart, this will be the categorical output.
#
# Make sure to de-dup any record.

# %% [markdown]
# **Prepare a dataframe for counting activity in the session**

# %%
# your code
# first just eliminate the records where event_type = "view" and drop NA values and duplicates

df_targets = df.loc[df["event_type"].isin(["cart", "purchase"])].drop_duplicates(
    subset=["event_type", "product_id", "price", "user_id", "user_session"]
)
cart_purchase_users = df.loc[
    df["event_type"].isin(["cart", "purchase"])
].drop_duplicates(subset=["user_id"])
cart_purchase_users.dropna(how="any", inplace=True)
cart_purchase_users_all_activity = df.loc[
    df["user_id"].isin(cart_purchase_users["user_id"])
]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-9437ee6e68db> in <module>
#       2 # first just eliminate the records where event_type = "view" and drop NA values and duplicates
#       3
# ----> 4 df_targets = df.loc[df["event_type"].isin(["cart", "purchase"])].drop_duplicates(
#       5     subset=["event_type", "product_id", "price", "user_id", "user_session"]
#       6 )
#
# NameError: name 'df' is not defined

# %%
# now you get the number of activities by user session

activity_in_session = (
    cart_purchase_users_all_activity.groupby(["user_session"])["event_type"]
    .count()
    .reset_index()
)
activity_in_session = activity_in_session.rename(
    columns={"event_type": "activity_count"}
)
df_targets = cart_purchase_users_all_activity.copy()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-a742a58b1f23> in <module>
#       2
#       3 activity_in_session = (
# ----> 4     cart_purchase_users_all_activity.groupby(["user_session"])["event_type"]
#       5     .count()
#       6     .reset_index()
#
# NameError: name 'cart_purchase_users_all_activity' is not defined

# %%
# create the two new columns for the category levels 1 and 2
# your code here

df_targets["category_level1"] = (
    df_targets["category_code"].str.split(".", expand=True)[0].astype("category")
)
df_targets["category_level2"] = (
    df_targets["category_code"].str.split(".", expand=True)[1].astype("category")
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-c9afa1c8ecc2> in <module>
#       3
#       4 df_targets["category_level1"] = (
# ----> 5     df_targets["category_code"].str.split(".", expand=True)[0].astype("category")
#       6 )
#       7 df_targets["category_level2"] = (
#
# NameError: name 'df_targets' is not defined

# %%
# Change the event_time to a timestamp
# your code
df_targets["timestamp"] = pd.to_datetime(df_targets["event_time"])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-c6587cfd0a87> in <module>
#       1 # Change the event_time to a timestamp
#       2 # your code
# ----> 3 df_targets["timestamp"] = pd.to_datetime(df_targets["event_time"])
#
# NameError: name 'df_targets' is not defined

# %%
# Use pandas.dt.dayofweek to get the day of the week
# your code
df_targets["weekday"] = df_targets["timestamp"].dt.dayofweek
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-24-fa9f5faf72de> in <module>
#       1 # Use pandas.dt.dayofweek to get the day of the week
#       2 # your code
# ----> 3 df_targets["weekday"] = df_targets["timestamp"].dt.dayofweek
#
# NameError: name 'df_targets' is not defined

# %%
# add the is_purchased feature
# your code

df_targets["is_purchased"] = np.where(df_targets["event_type"] == "purchase", 1, 0)
df_targets["is_purchased"] = df_targets.groupby(["user_session", "product_id"])[
    "is_purchased"
].transform("max")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-25-4074cbfe3336> in <module>
#       2 # your code
#       3
# ----> 4 df_targets["is_purchased"] = np.where(df_targets["event_type"] == "purchase", 1, 0)
#       5 df_targets["is_purchased"] = df_targets.groupby(["user_session", "product_id"])[
#       6     "is_purchased"
#
# NameError: name 'df_targets' is not defined

# %%
df_targets = df_targets.merge(activity_in_session, on="user_session", how="left")
df_targets["activity_count"] = df_targets["activity_count"].fillna(0)
df_targets["brand"] = df_targets["brand"].astype("category")
df_targets.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-26-96d321addf7a> in <module>
# ----> 1 df_targets = df_targets.merge(activity_in_session, on="user_session", how="left")
#       2 df_targets["activity_count"] = df_targets["activity_count"].fillna(0)
#       3 df_targets["brand"] = df_targets["brand"].astype("category")
#       4 df_targets.head()
#
# NameError: name 'df_targets' is not defined

# %% [markdown]
# ### Save new data structure if desired

# %%
# df_targets.to_csv('training_data.csv')

features = downsampled.loc[
    :,
    [
        "brand",
        "price",
        "weekday",
        "category_level1",
        "category_level2",
        "activity_count",
    ],
]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-27-a414619e7e62> in <module>
#       1 # df_targets.to_csv('training_data.csv')
#       2
# ----> 3 features = downsampled.loc[
#       4     :,
#       5     [
#
# NameError: name 'downsampled' is not defined

# %%
df_targets.info()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-28-fb2cd42bc13e> in <module>
# ----> 1 df_targets.info()
#
# NameError: name 'df_targets' is not defined

# %%
from sklearn.preprocessing import LabelEncoder, MinMaxScaler
from sklearn.model_selection import train_test_split
from xgboost import plot_importance
from sklearn.utils import resample
from sklearn import metrics

# %% [markdown]
# ## Resampling training set

# %%
is_purcahase_set = df_targets[df_targets["is_purchased"] == 1]
is_purcahase_set.shape[0]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-30-b2cd9b9e0f07> in <module>
# ----> 1 is_purcahase_set = df_targets[df_targets["is_purchased"] == 1]
#       2 is_purcahase_set.shape[0]
#
# NameError: name 'df_targets' is not defined

# %%
not_purcahase_set = df_targets[df_targets["is_purchased"] == 0]
not_purcahase_set.shape[0]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-31-1afb505854ca> in <module>
# ----> 1 not_purcahase_set = df_targets[df_targets["is_purchased"] == 0]
#       2 not_purcahase_set.shape[0]
#
# NameError: name 'df_targets' is not defined

# %%
n_samples = 500000
is_purchase_downsampled = resample(
    is_purcahase_set, replace=False, n_samples=n_samples, random_state=27
)
not_purcahase_set_downsampled = resample(
    not_purcahase_set, replace=False, n_samples=n_samples, random_state=27
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-32-43caeacb592f> in <module>
#       1 n_samples = 500000
#       2 is_purchase_downsampled = resample(
# ----> 3     is_purcahase_set, replace=False, n_samples=n_samples, random_state=27
#       4 )
#       5 not_purcahase_set_downsampled = resample(
#
# NameError: name 'is_purcahase_set' is not defined

# %%
downsampled = pd.concat([is_purchase_downsampled, not_purcahase_set_downsampled])
downsampled["is_purchased"].value_counts()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-33-a3517b86fb6c> in <module>
# ----> 1 downsampled = pd.concat([is_purchase_downsampled, not_purcahase_set_downsampled])
#       2 downsampled["is_purchased"].value_counts()
#
# NameError: name 'is_purchase_downsampled' is not defined

# %%
# select the brand, price, weekday, category_level1, cateogry_level2, and activity_count features

features = X_train, X_test, y_train, y_test = train_test_split(
    features, is_purchased, test_size=0.3, random_state=86
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-34-d8a81137815c> in <module>
#       2
#       3 features = X_train, X_test, y_train, y_test = train_test_split(
# ----> 4     features, is_purchased, test_size=0.3, random_state=86
#       5 )
#
# NameError: name 'features' is not defined

# %% [markdown]
# ## Encode categorical variables

# %%
features.loc[:, "brand"] = LabelEncoder().fit_transform(
    downsampled.loc[:, "brand"].copy()
)
features.loc[:, "weekday"] = LabelEncoder().fit_transform(
    downsampled.loc[:, "weekday"].copy()
)
features.loc[:, "category_level1"] = LabelEncoder().fit_transform(
    downsampled.loc[:, "category_level1"].copy()
)
features.loc[:, "category_level2"] = LabelEncoder().fit_transform(
    downsampled.loc[:, "category_level2"].copy()
)

is_purchased = LabelEncoder().fit_transform(downsampled["is_purchased"])
features.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-35-13a3951bff8e> in <module>
#       1 features.loc[:, "brand"] = LabelEncoder().fit_transform(
# ----> 2     downsampled.loc[:, "brand"].copy()
#       3 )
#       4 features.loc[:, "weekday"] = LabelEncoder().fit_transform(
#       5     downsampled.loc[:, "weekday"].copy()
#
# NameError: name 'downsampled' is not defined

# %%
print(list(features.columns))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-36-9dcf11905214> in <module>
# ----> 1 print(list(features.columns))
#
# NameError: name 'features' is not defined

# %% [markdown]
# ## Split the data
# Use a test size of 0.3 and a random state of 86 to split the data into test and train subsets

# %%
X_train, X_test, y_train, y_test = X_train, X_test, y_train, y_test = train_test_split(
    features, is_purchased, test_size=0.3, random_state=86
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-37-21029b5cf2cd> in <module>
#       1 X_train, X_test, y_train, y_test = X_train, X_test, y_train, y_test = train_test_split(
# ----> 2     features, is_purchased, test_size=0.3, random_state=86
#       3 )
#
# NameError: name 'features' is not defined

# %% [markdown]
# ## Train the model
# Choose learning rate of 0.1 on XGBClassifier, fit the model, and make predictions on the test set

# %%
from xgboost import XGBClassifier

from xgboost import XGBClassifier

model = XGBClassifier(learning_rate=0.1)
model.fit(X_train, y_train)
y_pred = model.predict(X_test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-38-d928a3d6feb1> in <module>
#       4
#       5 model = XGBClassifier(learning_rate=0.1)
# ----> 6 model.fit(X_train, y_train)
#       7 y_pred = model.predict(X_test)
#
# NameError: name 'X_train' is not defined

# %%
print("Accuracy:", metrics.accuracy_score(y_test, y_pred))
print("Precision:", metrics.precision_score(y_test, y_pred))
print("Recall:", metrics.recall_score(y_test, y_pred))
print("fbeta:", metrics.fbeta_score(y_test, y_pred, average="weighted", beta=0.5))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-39-0a7d390eb8e4> in <module>
# ----> 1 print("Accuracy:", metrics.accuracy_score(y_test, y_pred))
#       2 print("Precision:", metrics.precision_score(y_test, y_pred))
#       3 print("Recall:", metrics.recall_score(y_test, y_pred))
#       4 print("fbeta:", metrics.fbeta_score(y_test, y_pred, average="weighted", beta=0.5))
#
# NameError: name 'y_test' is not defined

# %% [markdown]
# ## Feature importance
# Plot the feature importance using plot_importance

# %%
from xgboost import XGBClassifier

model = XGBClassifier(learning_rate=0.1)
model.fit(X_train, y_train)
y_pred = model.predict(X_test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-40-54d1a525d6af> in <module>
#       2
#       3 model = XGBClassifier(learning_rate=0.1)
# ----> 4 model.fit(X_train, y_train)
#       5 y_pred = model.predict(X_test)
#
# NameError: name 'X_train' is not defined
